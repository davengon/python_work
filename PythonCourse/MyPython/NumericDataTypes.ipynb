# %%
x = 101
y = 123456789012345

# %%
print(x)
print(y)
# Out:
# 101
# 123456789012345

# %%
import sys
sys.getsizeof(x)
# Out:
# 28

# %%
sys.getsizeof(y)
# Out:
# 32

# %%
id(x)
# Out:
# 140704317912632

# %%
x = 205
id(x)
# Out:
# 140704317915960

# %%
a = 29.75
b = -1.75
c = -2.5E2
d = -3.1E-2

# %%
print(a, b, c, d)
# Out:
# 29.75 -1.75 -250.0 -0.031

# %%
c = 10 + 5j
print(type(c))
# Out:
# <class 'complex'>

# %%
c
# Out:
# (10+5j)

# %%
c = complex(5, 3.1)
print(c)
# Out:
# (5+3.1j)
