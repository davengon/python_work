# %%
s1 = bin(10)
s2 = oct(10)
s3 = hex(10)

print(s1, s2, s3)
# Out:
# 0b1010 0o12 0xa

# %%
type(s1)
# Out:
# str

# %%
s1 = bin(15)
s2 = oct(15)
s3 = hex(15)

# %%
print(s1, s2, s3)
# Out:
# 0b1111 0o17 0xf

# %%
s1 = bin(True)

# %%
print(s1)
# Out:
# 0b1

# %%
s1 = bin(1.0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 s1 = bin(1.0)
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
f = 16.59
b = True
s1 = '125'
s2 = '0b1010'
s3 = '0xA'

# %%
x = int(f)
print(x, type(x))
# Out:
# 16 <class 'int'>

# %%
x = int(b)
print(x, type(x))
# Out:
# 1 <class 'int'>

# %%
x = int(s3, 16)
print(x, type(x))
# Out:
# 10 <class 'int'>
